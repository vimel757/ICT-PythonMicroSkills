# %% [markdown]
# Question 1

# %%
name=input("Enter the name")
roll=int(input("Enter the roll number"))
mark=int(input("Enter the mark"))
print("name:",name)
print("Roll No:",roll)
print("Mark:",mark)
# Out:
# Enter the nameAnisha
# Enter the roll number21
# Enter the mark78
# name: Anisha
# Roll No: 21
# Mark: 78

# %% [markdown]
# **Question 2**

# %%
fahrenheit = float(input("Temperature in Fahrenheit: "))
celsius = (fahrenheit - 32) * 5/9
print("Temperature in Celsius:", celsius)
# Out:
# Temperature in Fahrenheit: 41
# Temperature in Celsius: 5.0

# %% [markdown]
# **Question3**

# %%
a=int(input("enter first number"))
b=int(input("enter secound number"))
c=a*b
print("The product of two numbers:",c)
# Out:
# enter first number2
# enter secound number3
# The product of two numbers: 6

# %% [markdown]
# **Question4**

# %%
input_string= "Learn Python by Developing a Website"
formatted_string = input_string.replace("Python","**Python**").replace("Website","**Website**")
print(formatted_string)
# Out:
# Learn **Python** by Developing a **Website**

# %% [markdown]
# Question5

# %%
r=int(input("enter the radius of circle"))
import math
area=math.pi*r*r
print("The area of circle is:",area)
# Out:
# enter the radius of circle2
# The area of circle is: 12.566370614359172

# %% [markdown]
# **Question6**

# %%
number=[10,20,30,40,50]
numbers=int(input("enter the number to be inserted"))
position=int(input("enter the position to insert the element"))
number.insert(position,numbers)
print("the new list",number)
# Out:
# enter the number to be inserted15
# enter the position to insert the element0
# the new list [15, 10, 20, 30, 40, 50]

# %% [markdown]
# **Question7**

# %%
sample_dict={"name":"jhon","age":5,"salary":8000,"city":"New York"}

sample_dict["location"]=sample_dict.pop("city")
sample_dict
# Out:
# {'name': 'jhon', 'age': 5, 'salary': 8000, 'location': 'New York'}

# %% [markdown]
# **Question8**

# %%
sample_dict={
    'emp1':{'name':'jhon','salary':7500},
    'emp2':{'name':'emma','salary':8000},
    'emp3':{'name':'brad','salary':500}
}


sample_dict['emp3']['salary']=8500
sample_dict['emp3']
# Out:
# {'name': 'brad', 'salary': 8500}

# %% [markdown]
# **Question9**

# %%
tuple1=(10,20,43,54,56,68)
tuple2=tuple1[2:-2]
tuple2
# Out:
# (43, 54)

# %% [markdown]
# **Question10**

# %%
tuple1=(50,10,60,70,50,83,567,50,81)
tuple1.count(50)
# Out:
# 3
